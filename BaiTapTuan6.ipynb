# %%
#Bai1
numbers = list(map(int, input().split()))
ketqua = []
for i in numbers:
    if i not in ketqua:
        ketqua.append(i)

print(ketqua)
# Out:
# [1, 2, 3, 4]

# %%
#Bai2
numbers = list(map(int, input().split()))
tong = 0
numbers1 = []
for i in numbers:
    tong += i
    numbers1.append(tong)
print(numbers1)
# Out:
# [1, 3, 6, 10]

# %%
#Bai3
danhsach = list(map(int, input().split()))
k = int(input())
ketqua = danhsach[k:] + danhsach[:k]
ketqua= tuple(ketqua)
print(ketqua)
# Out:
# (3, 4, 5, 1, 2)

# %%
#Bai4
import re
lst = list(re.split(r'[: ]', input()))
dic = {}
key_list = []
value_list = []
for i in range(0,len(lst)):
    if i % 2 == 0:
        key_list.append(lst[i])
    else:
        value_list.append(lst[i])

for i in range(0,len(key_list)):
    if key_list[i] not in dic:
        dic[key_list[i]] = []
    dic[key_list[i]].append(value_list[i])
    
print(dic)
# Out:
# {'a': ['1'], 'b': ['1'], 'c': ['1']}

# %%
#Bai5
numbers = list(map(int, input().split()))
p, n, z = 0, 0, 0
for i in numbers:
    if i > 0:
        p += 1
    elif i < 0:
        n += 1
    else:
        z += 1

ketqua = {
    "positives" : p,
    "negatives" : n,
    "zeros" : z
}
print(ketqua)
# Out:
# {'positives': 3, 'negatives': 2, 'zeros': 1}

# %%
#Bai6
numbers = list(map(int, input().split()))
tong = 0
for i in numbers:
    tong += i
    
print(tong)
# Out:
# 15

# %%
#Bai7
x = tuple(map(str, input().split()))
y = list(x)
z = y.reverse()
z = tuple(y)
print(z)
# Out:
# ('567', '345', '123')

# %%
#Bai8
dachsach = input().split()
ketqua = {}
for i in danhsach:
    if i in ketqua:
        ketqua[i] += 1
    else:
        ketqua[i] = 1
        
print(ketqua)
# Out:
# {1: 1, 2: 1, 3: 1, 4: 1, 5: 1}
