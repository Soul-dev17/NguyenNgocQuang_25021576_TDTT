# %%
#Bai1
n = int(input("nhap so nguyen n:"))
sum = 0
for i in range(1, n+1):
    sum += i
print(sum)
# Out:
# 5050

# %%
#Bai2 chua xong
n = int(input("nhap so nguyen n:"))
am = True
while am:
    if n < 0:
        print("vui long nhap lai so nguyen n!")
        n = int(input("nhap so nguyen n:"))
    else:
        am = False
# Out:
# 13 khong phai la so nguyen to
# 13 la so nguyen to
# 13 la so nguyen to
# 13 la so nguyen to
# 13 la so nguyen to
# 13 la so nguyen to
# 13 la so nguyen to
# 13 la so nguyen to
# 13 la so nguyen to
# 13 la so nguyen to
# 13 la so nguyen to
# 13 la so nguyen to
# 13 khong phai la so nguyen to

# %%
#Bai3
