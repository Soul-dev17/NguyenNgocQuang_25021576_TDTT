# %%
#Bai1
a, b = map(int, input("nhap 2 so nguyen:").split())
a = a ^ b
b = a ^ b
a = a ^ b
print(a, b)
# Out:
# 8 5

# %%
#Bai2
n = int(input("nhap so nguyen n: "))
if n > 0 and (n and (n - 1)) == 0:
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
#Bai3
m = int(input("nhap so m: "))
n = int(input("nhap so n: "))
ket_qua = m // n
print("Ket qua chia lam tron xuong:", ket_qua)
# Out:
# Ket qua chia lam tron xuong: 2

# %%
#Bai4
m = int(input("nhap so m: "))
n = int(input("nhap so n: "))
ket_qua = (m + n - 1) // n
print("Ket qua chia lam tron len:", ket_qua)
# Out:
# Ket qua chia lam tron len: 6

# %%
#Bai5
a = int(input("nhap so nguyen duong:"))
if a % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# 5 la so le

# %%
#Bai6
a, b = map(int, input("nhap 2 so nguyen:").split())
if a < 0 and b < 0:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
#Bai7
a, b = map(str, input("nhap 2 chuoi ki tu:").split())
if len(a) > len(b):
    print("True")
else:
    print("False")
# Out:
# True

# %%
#Bai8
a, b, c = map(int, input("nhap 3 so nguyen:").split())
if a + b > c and a + c > b and b + c > a:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
#Bai9
a, b ,c ,d = map(int, input("nhap 4 so nguyen:").split())
if a > b and a > c and a > d:
    print("so lon nhat la: ", a)
elif b > a and b > c and b > d:
    print("so lon nhat la: ", b)
elif c > a and c > b and c > d:
    print("so lon nhat la: ", c)
else:
    print("so lon nhat la: ", d)
# Out:
# so lon nhat la:  5234

# %%
#Bai10
a, b, c = map(int, input("nhap 3 so nguyen:").split())
if a**2 + b**2 == c**2 or a**2 + c**2 == b**2 or b**2 + c**2 == a**2:
    print("3 so tren tao thanh canh cua tam giac vuong")
elif a == b or a == c or b == c:
    print("3 so tren tao thanh canh cua tam giac can")
elif a == b == c:
    print("3 so tren tao thanh canh cua tam giac deu")
elif a+b > c and a+c > b and b+c > a:
    print("3 so tren tao thanh canh cua tam giac thuong")
else:
    print("3 so tren khong tao thanh canh cua tam giac")
# Out:
# 3 so tren tao thanh canh cua tam giac vuong

# %%
#Bai11
nam = int(input("nhap nam can kiem tra:"))
if (nam % 4 == 0 and nam % 100 != 0) or (nam % 400 == 0):
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
#Bai12
a, b = map(float, input("nhap 2 so nguyen:").split())
x = -b/a
print("nghiem cua phuong trinh la: ", "{:.2f}".format(x))
# Out:
# nghiem cua phuong trinh la:  -1001.09

# %%
#Bai13
diem = float(input("nhap diem cua hoc sinh:"))
if diem > 8.0:
    print("Gioi")
elif diem >= 6.5:
    print("Kha")
elif diem >= 5.0:
    print("Trung binh")
else:
    print("Yeu")
# Out:
# Kha

# %%
#Bai14

# %%
#Bai15
