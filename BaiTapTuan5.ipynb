# %%
#Bai1
def max_of_two():
    a, b = map(int, input("nhap hai so:").split())
    if a > b:
        return a
    else:
        return b

print(f"so lon hon la: {max_of_two()}")
# Out:
#   Cell In[1], line 2
#     def max_of_two:
#                   ^
# SyntaxError: expected '('

# %%
#Bai2
