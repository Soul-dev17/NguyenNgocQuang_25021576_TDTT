# %%
print("HelloWorld!")
# Out:
# HelloWorld!

# %%
name = input("Nhap ten cua ban: ")
print(name)
# Out:
# khang

# %%
a = input("nhap 1 so a:")
b = input("nhap 1 so b:")
print("tong 2 so la:", int(a) + int(b))
print("hieu 2 so la:", int(a) - int(b))
print("tich 2 so la:", int(a) * int(b))
print("thuong 2 so la:", int(a) // int(b))
print("chia lay du 2 so la:", int(a) % int(b))
# Out:
# tong 2 so la: 13
# hieu 2 so la: -1
# tich 2 so la: 42
# thuong 2 so la: 0
# chia lay du 2 so la: 6

# %%
a1, b1, c1, a2, b2, a3 = input("nhap lan luot cac diem:").split()
diemtrungbinh=(a1 + b1 + c1 + (a2+b2)*2 + a3*3)/10
print("diem trung binh la:", diemtrungbinh)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 a1, b1, c1, a2, b2, a3 = input("nhap lan luot cac diem:").split()
# ----> 2 diemtrungbinh=(a1 + b1 + c1 + (a2+b2)*2 + a3*3)/10
#       3 print("diem trung binh la:", diemtrungbinh)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
